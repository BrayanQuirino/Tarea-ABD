# %% [markdown]
# # Practica 1

# %%
conda install -c conda-forge/label/gcc7 missingno
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - missingno
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.2                |           py37_0         2.8 MB
#     missingno-0.4.1            |             py_0          10 KB  conda-forge/label/gcc7
#     ------------------------------------------------------------
#                                            Total:         2.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   missingno          conda-forge/label/gcc7/noarch::missingno-0.4.1-py_0
#
# The following packages will be UPDATED:
#
#   conda                                       4.7.12-py37_0 --> 4.8.2-py37_0
#
#
#
# ...
#
# conda-4.8.2          | 2.8 MB    |            |   0%
# conda-4.8.2          | 2.8 MB    |            |   1%
# ...

# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
#https://www.inegi.org.mx/programas/enigh/nc/2018/default.html#
path='conjunto_de_datos_viviendas_enigh_2018_ns.csv'
df=pd.read_csv(path,encoding='latin',error_bad_lines=False)
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (4,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     folioviv tipo_viv  mat_pared  mat_techos mat_pisos antiguedad antigua_ne  \
# 0  100013601        1          8          10         3         42
# 1  100013602        1          8          10         3         40
# 2  100013603        1          8          10         3         50
# 3  100013604        1          8          10         3         45
# 4  100013606        1          8          10         3         40
#
#    cocina cocina_dor  cuart_dorm  ...  tot_hom  tot_muj tot_hog  ubica_geo  \
# 0       1          2           4  ...        2        1       1       1001
# 1       1          2           5  ...        2        3       1       1001
# 2       1          2           2  ...        1        1       1       1001
# ...

# %% [markdown]
# General Stats

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73405 entries, 0 to 73404
# Data columns (total 64 columns):
# folioviv       73405 non-null int64
# tipo_viv       73405 non-null object
# mat_pared      73405 non-null int64
# mat_techos     73405 non-null int64
# mat_pisos      73405 non-null object
# antiguedad     73405 non-null object
# antigua_ne     73405 non-null object
# cocina         73405 non-null int64
# cocina_dor     73405 non-null object
# cuart_dorm     73405 non-null int64
# num_cuarto     73405 non-null int64
# disp_agua      73405 non-null int64
# dotac_agua     73405 non-null object
# excusado       73405 non-null int64
# uso_compar     73405 non-null object
# sanit_agua     73405 non-null object
# biodigest      73405 non-null object
# bano_comp      73405 non-null object
# bano_excus     73405 non-null object
# bano_regad     73405 non-null object
# drenaje        73405 non-null int64
# disp_elect     73405 non-null int64
# ...

# %% [markdown]
# Shape of dataframe

# %%
df.shape
# Out:
# (73405, 64)

# %%
#Number of rows
df.shape[0]
# Out:
# 73405

# %%
#Number of columns
df.shape[1]
# Out:
# 64

# %%
# Column names 
df.columns.values.tolist()
# Out:
# ['folioviv',
#  'tipo_viv',
#  'mat_pared',
#  'mat_techos',
#  'mat_pisos',
#  'antiguedad',
#  'antigua_ne',
#  'cocina',
#  'cocina_dor',
#  'cuart_dorm',
#  'num_cuarto',
#  'disp_agua',
#  'dotac_agua',
#  'excusado',
#  'uso_compar',
#  'sanit_agua',
#  'biodigest',
#  'bano_comp',
#  'bano_excus',
#  'bano_regad',
#  'drenaje',
#  'disp_elect',
#  'focos_inca',
#  'focos_ahor',
#  'combustible',
#  'estufa_chi',
#  'eli_basura',
#  'tenencia',
#  'renta',
#  'estim_pago',
#  'pago_viv',
#  'pago_mesp',
#  'tipo_adqui',
#  'viv_usada',
#  'tipo_finan',
#  'num_dueno1',
#  'hog_dueno1',
#  'num_dueno2',
#  'hog_dueno2',
#  'escrituras',
#  'lavadero',
#  'fregadero',
#  'regadera',
#  'tinaco_azo',
#  'cisterna',
#  'pileta',
#  'calent_sol',
#  'calent_gas',
#  'medidor_luz',
#  'bomba_agua',
#  'tanque_gas',
#  'aire_acond',
#  'calefacc',
#  'tot_resid',
#  'tot_hom',
#  'tot_muj',
#  'tot_hog',
#  'ubica_geo',
#  'tam_loc',
#  'est_socio',
#  'est_dis',
#  'upm',
# ...

# %%
#Column data type
df.dtypes
# Out:
# folioviv       int64
# tipo_viv      object
# mat_pared      int64
# mat_techos     int64
# mat_pisos     object
#                ...
# est_socio      int64
# est_dis        int64
# upm            int64
# factor         int64
# procaptar      int64
# Length: 64, dtype: object

# %%
#Are the missing values?

# %%
df.isnull().any().any()
# Out:
# False

# %%
msno.matrix(df)

# %%
df.replace({' ':np.nan}, inplace=True)

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %%
#Columns with missing values
df.columns[df.isnull().any()].tolist()
# Out:
# ['antiguedad',
#  'antigua_ne',
#  'cocina_dor',
#  'dotac_agua',
#  'uso_compar',
#  'sanit_agua',
#  'biodigest',
#  'bano_comp',
#  'bano_excus',
#  'bano_regad',
#  'focos_inca',
#  'focos_ahor',
#  'estufa_chi',
#  'renta',
#  'estim_pago',
#  'pago_viv',
#  'pago_mesp',
#  'tipo_adqui',
#  'viv_usada',
#  'tipo_finan',
#  'num_dueno1',
#  'hog_dueno1',
#  'num_dueno2',
#  'hog_dueno2',
#  'escrituras']

# %%
#Number of rows with missing values

#Sumary stats

df.describe()
# Out:
#            folioviv     mat_pared    mat_techos        cocina    cuart_dorm  \
# count  7.340500e+04  73405.000000  73405.000000  73405.000000  73405.000000
# mean   1.614521e+09      7.746707      8.263443      1.079273      2.029576
# std    9.310381e+08      0.764356      2.840912      0.270165      0.903999
# min    1.000136e+08      1.000000      1.000000      1.000000      1.000000
# 25%    8.044994e+08      8.000000      7.000000      1.000000      1.000000
# 50%    1.562126e+09      8.000000     10.000000      1.000000      2.000000
# 75%    2.403854e+09      8.000000     10.000000      1.000000      3.000000
# max    3.260799e+09      8.000000     10.000000      2.000000     11.000000
#
#          num_cuarto     disp_agua      excusado       drenaje    disp_elect  \
# count  73405.000000  73405.000000  73405.000000  73405.000000  73405.000000
# mean       3.671289      1.626156      1.027205      1.563013      1.052789
# ...

# %%
#Select specific row index

df.loc[[0]]
# Out:
#     folioviv tipo_viv  mat_pared  mat_techos mat_pisos antiguedad antigua_ne  \
# 0  100013601        1          8          10         3         42        NaN
#
#    cocina cocina_dor  cuart_dorm  ...  tot_hom  tot_muj tot_hog  ubica_geo  \
# 0       1          2           4  ...        2        1       1       1001
#
#   tam_loc est_socio est_dis upm factor procaptar
# 0       1         3       2   1    175         0
#
# [1 rows x 64 columns]

# %%
#Select specific row indices
df.loc[30:33]
# Out:
#      folioviv tipo_viv  mat_pared  mat_techos mat_pisos antiguedad antigua_ne  \
# 30  100062804        1          8          10         3        NaN          1
# 31  100062805        1          8          10         3         30        NaN
# 32  100062806        1          8          10         3         30        NaN
# 33  100067401        1          8          10         3         35        NaN
#
#     cocina cocina_dor  cuart_dorm  ...  tot_hom  tot_muj tot_hog  ubica_geo  \
# 30       2        NaN           1  ...        1        1       1       1001
# 31       1          2           3  ...        0        1       1       1001
# 32       1          2           1  ...        0        1       1       1001
# 33       1          2           2  ...        1        2       1       1001
#
#    tam_loc est_socio est_dis upm factor procaptar
# 30       1         3       2   7    188         0
# 31       1         3       2   7    188         0
# ...

# %%
#Excluding specific row indices
df.drop([0,24,51],axis=0).head()
# Out:
#     folioviv tipo_viv  mat_pared  mat_techos mat_pisos antiguedad antigua_ne  \
# 1  100013602        1          8          10         3         40        NaN
# 2  100013603        1          8          10         3         50        NaN
# 3  100013604        1          8          10         3         45        NaN
# 4  100013606        1          8          10         3         40        NaN
# 5  100026701        1          8          10         3          5        NaN
#
#    cocina cocina_dor  cuart_dorm  ...  tot_hom  tot_muj tot_hog  ubica_geo  \
# 1       1          2           5  ...        2        3       1       1001
# 2       1          2           2  ...        1        1       1       1001
# 3       1          2           2  ...        1        1       1       1001
# 4       1          2           3  ...        1        3       1       1001
# 5       1          2           3  ...        2        2       1       1001
#
#   tam_loc est_socio est_dis upm factor procaptar
# ...

# %%
#Excluding Specific Range Row indices
df.drop(df.index[1:5],axis=0).head(10)
# Out:
#      folioviv tipo_viv  mat_pared  mat_techos mat_pisos antiguedad antigua_ne  \
# 0   100013601        1          8          10         3         42        NaN
# 5   100026701        1          8          10         3          5        NaN
# 6   100026703        1          8          10         3         25        NaN
# 7   100026704        1          8          10         3         30        NaN
# 8   100026706        3          8          10         2          1        NaN
# 9   100027201        1          8          10         3         30        NaN
# 10  100027202        1          8          10         3         30        NaN
# 11  100027204        1          8          10         3         40        NaN
# 12  100027205        1          8          10         3         35        NaN
# 13  100045501        1          8          10         3        NaN          1
#
#     cocina cocina_dor  cuart_dorm  ...  tot_hom  tot_muj tot_hog  ubica_geo  \
# ...

# %%
#Subsetting based on offset from top (bottom)
df[100:].head()
# Out:
#       folioviv tipo_viv  mat_pared  mat_techos mat_pisos antiguedad  \
# 100  100113502        1          8          10         3         30
# 101  100113503        1          8          10         3         50
# 102  100113505        1          8          10         3         20
# 103  100113506        1          8          10         3         25
# 104  100154201        1          8          10         3         40
#
#     antigua_ne  cocina cocina_dor  cuart_dorm  ...  tot_hom  tot_muj tot_hog  \
# 100        NaN       1          2           3  ...        1        0       1
# 101        NaN       1          2           1  ...        1        0       1
# 102        NaN       1          2           2  ...        1        4       1
# 103        NaN       1          2           2  ...        2        0       1
# 104        NaN       1          2           2  ...        0        1       1
#
#      ubica_geo tam_loc est_socio est_dis upm factor procaptar
# ...

# %%
#Get values from crime
df.cocina.values
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
df['cocina'].values
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
df.cocina.unique()
# Out:
# array([1, 2], dtype=int64)

# %%
df.cocina.value_counts()
# Out:
# 1    67586
# 2     5819
# Name: cocina, dtype: int64

# %%
#Get the number of unique for each column
df.agg(['count','size','nunique'])
# Out:
#          folioviv  tipo_viv  mat_pared  mat_techos  mat_pisos  antiguedad  \
# count       73405     73405      73405       73405      73405       62501
# size        73405     73405      73405       73405      73405       73405
# nunique     73405         6          8          10          7          97
#
#          antigua_ne  cocina  cocina_dor  cuart_dorm  ...  tot_hom  tot_muj  \
# count         10904   73405       67586       73405  ...    73405    73405
# size          73405   73405       73405       73405  ...    73405    73405
# nunique           1       2           2          11  ...       12       13
#
#          tot_hog  ubica_geo  tam_loc  est_socio  est_dis    upm  factor  \
# count      73405      73405    73405      73405    73405  73405   73405
# size       73405      73405    73405      73405    73405  73405   73405
# nunique        5        996        4          4      543   8377    1747
#
#          procaptar
# count        73405
# size         73405
# ...

# %%
df.groupby('cocina').agg(['count','size','nunique']).stack()
# Out:
#                 folioviv  tipo_viv  mat_pared  mat_techos  mat_pisos  \
# cocina
# 1      count       67586     67586      67586       67586      67586
#        size        67586     67586      67586       67586      67586
#        nunique     67586         6          8          10          7
# 2      count        5819      5819       5819        5819       5819
#        size         5819      5819       5819        5819       5819
#        nunique      5819         6          8          10          6
#
#                 antiguedad  antigua_ne  cocina_dor  cuart_dorm  num_cuarto  \
# cocina
# 1      count         57536       10050       67586       67586       67586
#        size          67586       67586       67586       67586       67586
#        nunique          97           1           2          11          20
# 2      count          4965         854           0        5819        5819
#        size           5819        5819        5819        5819        5819
# ...

# %%
df.groupby('cocina').agg(['count','size','nunique'])
# Out:
#        folioviv                tipo_viv                mat_pared         \
#           count   size nunique    count   size nunique     count   size
# cocina
# 1         67586  67586   67586    67586  67586       6     67586  67586
# 2          5819   5819    5819     5819   5819       6      5819   5819
#
#                mat_techos  ... est_dis    upm                factor         \
#        nunique      count  ... nunique  count   size nunique  count   size
# cocina                     ...
# 1            8      67586  ...     543  67586  67586    8371  67586  67586
# 2            8       5819  ...     422   5819   5819    2397   5819   5819
#
#                procaptar
#        nunique     count   size nunique
# cocina
# 1         1747     67586  67586       2
# 2          969      5819   5819       2
#
# [2 rows x 189 columns]

# %%
dfSample=df.sample(frac=0.05,random_state=1)
dfSample.head()
# Out:
#          folioviv tipo_viv  mat_pared  mat_techos mat_pisos antiguedad  \
# 17965   802842401        1          8          10         3        NaN
# 71827  3201220213        1          8          10         3         22
# 61595  2701356723        1          8          10         3        NaN
# 18885   806379802        1          8           7         2          4
# 55697  2460567014        1          7           3         2         27
#
#       antigua_ne  cocina cocina_dor  cuart_dorm  ...  tot_hom  tot_muj  \
# 17965          1       1          2           2  ...        0        1
# 71827        NaN       1          2           1  ...        1        1
# 61595          1       1          2           2  ...        3        1
# 18885        NaN       1          2           1  ...        0        1
# 55697        NaN       1          2           3  ...        3        2
#
#       tot_hog  ubica_geo tam_loc est_socio est_dis   upm factor procaptar
# ...

# %%
df.shape
# Out:
# (73405, 64)

# %%
dfSample.shape
# Out:
# (3670, 64)

# %% [markdown]
# # Data transform
#
# Drop rows with missing count

# %%
dfDropped=df.dropna(subset=['antiguedad'])
dfDropped.head()
# Out:
#     folioviv tipo_viv  mat_pared  mat_techos mat_pisos antiguedad antigua_ne  \
# 0  100013601        1          8          10         3         42        NaN
# 1  100013602        1          8          10         3         40        NaN
# 2  100013603        1          8          10         3         50        NaN
# 3  100013604        1          8          10         3         45        NaN
# 4  100013606        1          8          10         3         40        NaN
#
#    cocina cocina_dor  cuart_dorm  ...  tot_hom  tot_muj tot_hog  ubica_geo  \
# 0       1          2           4  ...        2        1       1       1001
# 1       1          2           5  ...        2        3       1       1001
# 2       1          2           2  ...        1        1       1       1001
# 3       1          2           2  ...        1        1       1       1001
# 4       1          2           3  ...        1        3       1       1001
#
#   tam_loc est_socio est_dis upm factor procaptar
# ...

# %%
dfDropped.shape
# Out:
# (62501, 64)

# %%
#Copy of df
dfCopy=df.copy()
dfCopy.head()
# Out:
#     folioviv tipo_viv  mat_pared  mat_techos mat_pisos antiguedad antigua_ne  \
# 0  100013601        1          8          10         3         42        NaN
# 1  100013602        1          8          10         3         40        NaN
# 2  100013603        1          8          10         3         50        NaN
# 3  100013604        1          8          10         3         45        NaN
# 4  100013606        1          8          10         3         40        NaN
#
#    cocina cocina_dor  cuart_dorm  ...  tot_hom  tot_muj tot_hog  ubica_geo  \
# 0       1          2           4  ...        2        1       1       1001
# 1       1          2           5  ...        2        3       1       1001
# 2       1          2           2  ...        1        1       1       1001
# 3       1          2           2  ...        1        1       1       1001
# 4       1          2           3  ...        1        3       1       1001
#
#   tam_loc est_socio est_dis upm factor procaptar
# ...

# %%
dfCopy.shape
# Out:
# (73405, 64)

# %%
dfDropped['tot_hom'].dtype
# Out:
# dtype('int64')

# %%
dfDropped['tot_hom'].mean()
# Out:
# 1.8132989872162046

# %%
dfCopy['tot_hom'].fillna(value=np.round(df['tot_hom'].mean(),decimals=0), inplace=True)

# %%
dfCopy.agg(['count','size','nunique'])
# Out:
#          folioviv  tipo_viv  mat_pared  mat_techos  mat_pisos  antiguedad  \
# count       73405     73405      73405       73405      73405       62501
# size        73405     73405      73405       73405      73405       73405
# nunique     73405         6          8          10          7          97
#
#          antigua_ne  cocina  cocina_dor  cuart_dorm  ...  tot_hom  tot_muj  \
# count         10904   73405       67586       73405  ...    73405    73405
# size          73405   73405       73405       73405  ...    73405    73405
# nunique           1       2           2          11  ...       12       13
#
#          tot_hog  ubica_geo  tam_loc  est_socio  est_dis    upm  factor  \
# count      73405      73405    73405      73405    73405  73405   73405
# size       73405      73405    73405      73405    73405  73405   73405
# nunique        5        996        4          4      543   8377    1747
#
#          procaptar
# count        73405
# size         73405
# ...

# %% [markdown]
# # Handling Categorical Data

# %%
list(df['tipo_viv'].unique())
# Out:
# ['1', '3', '2', '5', '&', '4']

# %%
"""
1 Casa independiente
2 Departamento en edificio
3 Vivienda en vecindad
4 Vivienda en cuarto de azotea
5 Local no construido para habitación
"""
df['tipo_viv'].replace({'1':"independiente", 
                       '2':"departamento",
                       '3':"vecindad", 
                       '4':"azotea", 
                       '5':"local",
                       '&':'NAN'}, inplace=True)

# %%
list(df['tipo_viv'].unique())
# Out:
# ['independiente', 'vecindad', 'departamento', 'local', 'NAN', 'azotea']

# %%
#Create a dictionary
keys=list(df['tipo_viv'].unique())
vals=range(1,7)
act=dict(zip(keys,vals))
act
# Out:
# {'independiente': 1,
#  'vecindad': 2,
#  'departamento': 3,
#  'local': 4,
#  'NAN': 5,
#  'azotea': 6}

# %%
dfCopy['tipoviv']=df['tipo_viv'].map(act)
dfCopy.head()
# Out:
#     folioviv tipo_viv  mat_pared  mat_techos mat_pisos antiguedad antigua_ne  \
# 0  100013601        1          8          10         3         42        NaN
# 1  100013602        1          8          10         3         40        NaN
# 2  100013603        1          8          10         3         50        NaN
# 3  100013604        1          8          10         3         45        NaN
# 4  100013606        1          8          10         3         40        NaN
#
#    cocina cocina_dor  cuart_dorm  ...  tot_muj  tot_hog ubica_geo  tam_loc  \
# 0       1          2           4  ...        1        1      1001        1
# 1       1          2           5  ...        3        1      1001        1
# 2       1          2           2  ...        1        1      1001        1
# 3       1          2           2  ...        1        1      1001        1
# 4       1          2           3  ...        3        1      1001        1
#
#   est_socio est_dis upm factor procaptar tipoviv
# ...

# %%
list(dfCopy['tipoviv'].unique())
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# # Data summarization

# %%
dfCopy['tot_hom'].mean()
# Out:
# 1.793842381309175

# %%
dfCopy['tot_hom'][dfCopy['tipoviv']==6]
# Out:
# 1902     4
# 2918     1
# 3158     1
# 4361     1
# 4391     1
#         ..
# 66584    2
# 66830    0
# 67864    2
# 70597    0
# 72073    1
# Name: tot_hom, Length: 99, dtype: int64

# %%
dfCopy['tot_hom'][dfCopy['tipoviv']==6].mean()
# Out:
# 1.4747474747474747

# %%
dfCopy.groupby(["tipoviv",'mat_pared','mat_techos','mat_pisos']).count()
# Out:
#                                         folioviv  tipo_viv  antiguedad  \
# tipoviv mat_pared mat_techos mat_pisos
# 1       1         1          1                 4         4           4
#                              2                 3         3           2
#                              1                 3         3           3
#                              2                 2         2           2
#                              3                 2         2           2
# ...                                          ...       ...         ...
# 6       8         9          2                 1         1           0
#                   10         2                27        27           8
#                              3                14        14           7
#                              2                 9         9           4
#                              3                21        21          12
#
#                                         antigua_ne  cocina  cocina_dor  \
# ...

# %%
dfCopy.groupby(["tipoviv",'mat_pared'])[['mat_techos','mat_pisos']].count()
# Out:
#                    mat_techos  mat_pisos
# tipoviv mat_pared
# 1       1                 133        133
#         2                 124        124
#         3                 407        407
#         4                 172        172
#         5                 264        264
#         6                3305       3305
#         7                6290       6290
#         8               58730      58730
# 2       1                   3          3
#         2                   3          3
#         3                  32         32
#         5                   3          3
#         6                  70         70
#         7                  35         35
#         8                1282       1282
# 3       8                1940       1940
# 4       1                   2          2
#         3                   2          2
#         5                   2          2
#         6                   6          6
#         7                  12         12
# ...

# %%
dfCopy.tipoviv
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 73400    1
# 73401    1
# 73402    1
# 73403    1
# 73404    1
# Name: tipoviv, Length: 73405, dtype: int64

# %%
dfSample=df.sample(frac=0.05,random_state=1)
dfSample.head()
# Out:
#          folioviv       tipo_viv  mat_pared  mat_techos mat_pisos antiguedad  \
# 17965   802842401  independiente          8          10         3        NaN
# 71827  3201220213  independiente          8          10         3         22
# 61595  2701356723  independiente          8          10         3        NaN
# 18885   806379802  independiente          8           7         2          4
# 55697  2460567014  independiente          7           3         2         27
#
#       antigua_ne  cocina cocina_dor  cuart_dorm  ...  tot_hom  tot_muj  \
# 17965          1       1          2           2  ...        0        1
# 71827        NaN       1          2           1  ...        1        1
# 61595          1       1          2           2  ...        3        1
# 18885        NaN       1          2           1  ...        0        1
# 55697        NaN       1          2           3  ...        3        2
#
#       tot_hog  ubica_geo tam_loc est_socio est_dis   upm factor procaptar
# ...

# %%
dfSample.groupby(["tipo_viv","mat_pared"])[["mat_techos","mat_pisos"]].agg([np.sum,np.mean,np.count_nonzero])
# Out:
#                         mat_techos
#                                sum       mean count_nonzero
# tipo_viv      mat_pared
# NAN           6                 10  10.000000             1
#               8                 12   6.000000             2
# azotea        7                  8   8.000000             1
#               8                 16   5.333333             3
# departamento  8               1190  10.000000           119
# independiente 1                 18   6.000000             3
#               2                 35   4.375000             8
#               3                 73   3.476190            21
#               4                 24   4.000000             6
#               5                 46   5.111111             9
#               6                767   4.916667           156
#               7               1890   6.000000           315
#               8              25816   8.736379          2955
# local         7                  8   8.000000             1
# ...

# %%
dfSample.groupby(["tipo_viv","mat_techos"]).agg({'tot_hom':np.mean,'mat_pared':np.max})
# Out:
#                            tot_hom  mat_pared
# tipo_viv      mat_techos
# NAN           5           2.000000          8
#               7           1.000000          8
#               10          1.000000          6
# azotea        3           1.000000          8
#               8           2.000000          7
#               10          2.000000          8
# departamento  10          1.579832          8
# independiente 1           1.571429          8
#               2           2.346154          8
#               3           1.853704          8
#               4           1.985714          8
#               5           1.461538          8
#               6           1.600000          8
#               7           1.771242          8
#               8           1.891304          8
#               9           2.000000          8
#               10          1.810732          8
# local         2           2.000000          8
#               3           2.500000          8
# ...

# %% [markdown]
# # Data visualization

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

ax1=plt.axes()
ax2=plt.axes([0.65,0.65,0.2,0.2])

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
           fontsize=18, ha='center')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
                      fontsize=18, ha='center')
fig

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
dfSample['tot_hom'] = dfSample['tot_hom'].astype('int64')

dfSample.plot(kind='scatter',x='tot_hom',y='mat_pared')

# %%
plt.hist(dfSample['mat_pared'])
plt.xlabel('mat_pared')
plt.ylabel('Frequency')
plt.title('Frequency of tipoact')
# Out:
# Text(0.5, 1.0, 'Frequency of tipoact')

# %%
plt.hist(dfSample['tot_hom'])
plt.xlabel('tot_hom')
plt.ylabel('Frequency')
plt.title('Frequency of tot_hom')
# Out:
# Text(0.5, 1.0, 'Frequency of tot_hom')

# %%
#plt.boxplot(df_sample['tot_hom'])
plt.boxplot(dfSample['tot_hom'], showmeans=True, meanline=True)
plt.ylabel('tot_hom count')
plt.title('Box Plot of tot_hom count')
# Out:
# Text(0.5, 1.0, 'Box Plot of tot_hom count')
